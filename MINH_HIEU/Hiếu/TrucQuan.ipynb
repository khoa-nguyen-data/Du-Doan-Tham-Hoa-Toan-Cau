# %% [markdown]
# # Truc Quan Du Lieu Tham Hoa Toan Cau 2018-2024
# ## Phan tich va Truc quan hoa Du lieu Thien tai The gioi

# %%
# Nhap cac thu vien can thiet
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
warnings.filterwarnings('ignore')

# Cau hinh giao dien dep
import plotly.io as pio

# Custom template dep hon
custom_template = go.layout.Template()
custom_template.layout = go.Layout(
    paper_bgcolor='rgba(17, 17, 27, 0.95)',
    plot_bgcolor='rgba(17, 17, 27, 0.95)',
    font=dict(family="Segoe UI, Arial", color="#E8E8E8"),
    title=dict(font=dict(size=20, color="#FFFFFF")),
    colorway=['#FF6B9D', '#C084FC', '#60A5FA', '#34D399', '#FBBF24', 
              '#F87171', '#A78BFA', '#38BDF8', '#4ADE80', '#FB923C'],
    hoverlabel=dict(
        bgcolor="rgba(30, 30, 46, 0.95)",
        font_size=12,
        font_family="Segoe UI"
    )
)
pio.templates["premium_dark"] = custom_template
pio.templates.default = "premium_dark"

# Gradient color palettes
NEON_COLORS = ['#FF006E', '#FB5607', '#FFBE0B', '#8338EC', '#3A86FF', 
               '#06FFA5', '#FF6B9D', '#C084FC', '#60A5FA', '#34D399']

GRADIENT_SCALES = {
    'fire': [[0, '#1a1a2e'], [0.25, '#e94560'], [0.5, '#ff6b6b'], [0.75, '#feca57'], [1, '#fff200']],
    'ocean': [[0, '#0c1445'], [0.25, '#1e3a5f'], [0.5, '#3498db'], [0.75, '#5dade2'], [1, '#85c1e9']],
    'forest': [[0, '#1a1a2e'], [0.25, '#155d27'], [0.5, '#2d6a4f'], [0.75, '#40916c'], [1, '#95d5b2']],
    'purple': [[0, '#1a1a2e'], [0.25, '#4a1a6b'], [0.5, '#7c3aed'], [0.75, '#a78bfa'], [1, '#ddd6fe']]
}

print("Da duoc cau hinh!")
print("Gradient Palettes: fire, ocean, forest, purple")
# Out:
# Da duoc cau hinh!
# Gradient Palettes: fire, ocean, forest, purple

# %%
# Doc du lieu
df = pd.read_csv('global_disaster_response_2018_2024.csv')

# Chuyen doi dinh dang ngay
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['month_name'] = df['date'].dt.strftime('%B')

# Lam sach du lieu - loai bo gia tri bat thuong
df = df[df['severity_index'] > 0]
df = df[df['casualties'] >= 0]
df = df[df['economic_loss_usd'] >= 0]

# Dich ten loai tham hoa sang tieng Viet
disaster_vn = {
    'Earthquake': 'Dong dat',
    'Flood': 'Lu lut',
    'Hurricane': 'Bao',
    'Wildfire': 'Chay rung',
    'Drought': 'Han han',
    'Tornado': 'Loc xoay',
    'Landslide': 'Sat lo dat',
    'Extreme Heat': 'Nang nong cuc doan',
    'Storm Surge': 'Bao bien',
    'Volcanic Eruption': 'Nui lua'
}
df['loai_tham_hoa'] = df['disaster_type'].map(disaster_vn)

month_vn = {
    'January': 'Th1', 'February': 'Th2', 'March': 'Th3',
    'April': 'Th4', 'May': 'Th5', 'June': 'Th6',
    'July': 'Th7', 'August': 'Th8', 'September': 'Th9',
    'October': 'Th10', 'November': 'Th11', 'December': 'Th12'
}
df['ten_thang'] = df['month_name'].map(month_vn)

# Hien thi thong tin
from IPython.display import HTML, display

info_html = f"""
<div style="background: linear-gradient(135deg, rgba(99, 102, 241, 0.1), rgba(168, 85, 247, 0.1)); 
            border-left: 4px solid #8B5CF6; padding: 20px; border-radius: 0 12px 12px 0; 
            font-family: 'Segoe UI', Arial; margin: 10px 0;">
    <h3 style="color: #A78BFA; margin: 0 0 15px 0; font-size: 18px;">
        📊 Du Lieu Da Duoc Tai Thanh Cong
    </h3>
    <div style="display: grid; grid-template-columns: repeat(2, 1fr); gap: 15px;">
        <div style="color: #E8E8E8;">
            <span style="color: #60A5FA;">🏷️ Loai tham hoa:</span> 
            <strong>{df['loai_tham_hoa'].nunique()}</strong>
        </div>
        <div style="color: #E8E8E8;">
            <span style="color: #34D399;">🌍 So quoc gia:</span> 
            <strong>{df['country'].nunique()}</strong>
        </div>
        <div style="color: #E8E8E8;">
            <span style="color: #FBBF24;">📅 Thoi gian:</span> 
            <strong>{df['date'].min().strftime('%d/%m/%Y')} - {df['date'].max().strftime('%d/%m/%Y')}</strong>
        </div>
        <div style="color: #E8E8E8;">
            <span style="color: #F87171;">📈 Tong su kien:</span> 
            <strong>{len(df):,}</strong>
        </div>
    </div>
</div>
"""
display(HTML(info_html))
# Out:
# <div style="background: linear-gradient(135deg, rgba(99, 102, 241, 0.1), rgba(168, 85, 247, 0.1));
#             border-left: 4px solid #8B5CF6; padding: 20px; border-radius: 0 12px 12px 0;
#             font-family: 'Segoe UI', Arial; margin: 10px 0;">
#     <h3 style="color: #A78BFA; margin: 0 0 15px 0; font-size: 18px;">
#         📊 Du Lieu Da Duoc Tai Thanh Cong
#     </h3>
#     <div style="display: grid; grid-template-columns: repeat(2, 1fr); gap: 15px;">
#         <div style="color: #E8E8E8;">
#             <span style="color: #60A5FA;">🏷️ Loai tham hoa:</span>
#             <strong>10</strong>
#         </div>
#         <div style="color: #E8E8E8;">
#             <span style="color: #34D399;">🌍 So quoc gia:</span>
#             <strong>20</strong>
#         </div>
#         <div style="color: #E8E8E8;">
#             <span style="color: #FBBF24;">📅 Thoi gian:</span>
#             <strong>01/01/2018 - 31/12/2024</strong>
#         </div>
#         <div style="color: #E8E8E8;">
#             <span style="color: #F87171;">📈 Tong su kien:</span>
#             <strong>50,000</strong>
#         </div>
#     </div>
# </div>

# %% [markdown]
# ## Phan Bo Loai Tham Hoa

# %%
# Bieu do phan bo loai tham hoa
disaster_counts = df['loai_tham_hoa'].value_counts().reset_index()
disaster_counts.columns = ['loai_tham_hoa', 'count']

# Sunburst chart
fig1 = px.sunburst(
    df,
    path=['loai_tham_hoa', 'country'],
    values='severity_index',
    color='severity_index',
    color_continuous_scale=GRADIENT_SCALES['fire'],
    title='PHAN BO THAM HOA THEO LOAI VA QUOC GIA'
)
fig1.update_layout(
    width=500, height=350,
    paper_bgcolor='rgba(17, 17, 27, 0.95)',
    font=dict(family="Segoe UI", size=11, color="#E8E8E8"),
    title=dict(font=dict(size=16, color="#FFFFFF"), x=0.5, y=0.98),
    margin=dict(t=50, b=10, l=10, r=10),
    coloraxis_showscale=False
)
fig1.update_traces(
    textinfo='label+percent entry', 
    insidetextorientation='radial',
    marker=dict(line=dict(color='rgba(255,255,255,0.3)', width=1))
)
fig1.show(config={'displayModeBar': False})

# Donut chart
fig2 = go.Figure(data=[go.Pie(
    labels=disaster_counts['loai_tham_hoa'],
    values=disaster_counts['count'],
    hole=0.5,
    marker=dict(
        colors=NEON_COLORS[:len(disaster_counts)],
        line=dict(color='rgba(17, 17, 27, 1)', width=2)
    ),
    textinfo='percent+label',
    textposition='inside',
    insidetextorientation='horizontal',
    textfont=dict(size=9, color='white'),
    pull=[0.02]*len(disaster_counts),
    hovertemplate='<b>%{label}</b><br>So luong: %{value:,}<br>Ty le: %{percent}<extra></extra>'
)])
fig2.add_annotation(
    text=f"<b>{len(df):,}</b><br><span style='font-size:10px'>Su kien</span>",
    x=0.5, y=0.5, font=dict(size=14, color='#FFFFFF'), showarrow=False
)
fig2.update_layout(
    title=dict(text='TY LE THAM HOA THEO LOAI', font=dict(size=14, color='#FFFFFF'), x=0.5),
    width=500, height=350,
    paper_bgcolor='rgba(17, 17, 27, 0.95)',
    font=dict(family="Segoe UI", color="#E8E8E8"),
    showlegend=True,
    legend=dict(
        orientation="v", 
        yanchor="middle", y=0.5, 
        xanchor="left", x=1.02,
        font=dict(size=8), 
        bgcolor='rgba(0,0,0,0)'
    ),
    margin=dict(t=50, b=20, l=20, r=100)
)
fig2.show(config={'displayModeBar': False})
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="10546be3-7a38-4021-b14a-563e88bb8c1c" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("10546be3-7a38-4021-b14a-563e88bb8c1c")) {                    Plotly.newPlot(                        "10546be3-7a38-4021-b14a-563e88bb8c1c",                        [{"branchvalues":"total","customdata":{"dtype":"f8","bdata":"cDGI50tgFkAHsO7evrwXQHSJ3WQLYBZAjsh5fcxkF0BiIaGAEbkWQKToxs6PeRZAZ80xpQLmFkD6R\u002fWL1P8VQHnqJutz3BZAJbPl8Uf8F0CJiBb8N10YQHHQ9CEUXhZAPpRSimxMF0CbJq4aWYUXQKP3THIuPhdANNuI\\u002f3uArztRdAkL8Mlm+ZF0DGuJvSus8WQNTcYFVwxBdADYxtx6WsFkBDik8dblsXQD2tpvP7ChdA1Nk7ZaAbF0CPKLM\u002f9BgXQPrK6XR5kxZAHoYWfMTTFkCjvtOaiI4XQGjFy7IGSBdAiOSHXmNTF0DO439MvGgXQD50Ux3wZBZAQmKjC\u002f6uFkDs0hc2CI0XQIToiy\u002fZjRhAwfB9SgK2FkAFRdif7GoWQM0BHStexRZAun0yKZ29FkCjOjI3oaQXQKNGnJ+HvRZA+fC5tMeWFkApkgHiawUXQLCkydmkuxZAEyoLA0RmF0CCLLE\u002fPNMWQBLvX5EjTRdABfR95p46F0CuHqJGpFAXQGbmpRE8gRdAGwUu6rC8F0B96F0yi90WQAqDZgt9YxdAhZmbFxceFkBIJ+6gTHcXQEo\u002foR+3vBZAEARFlqHcFkAyBElRFmgXQIyBEgxBnxZAANAdHOuzF0DNsdsc+xcXQNtU1AJLWRdAHBdIP3vYFkBW8tSS6r0WQB0WBnOZtBZAMZBtyO2sFkB2XYAgYcQXQENEW2tzBxdAWK\u002f91iejF0A6WsASomQXQKTf5gpkuxZAXyyqTaFtF0C+3FO7oI0YQNDpZz7yVhZA4nZNjVUnF0BTaz4qoMwWQKLDwzA1SBdA5\u002fLqNDdYF0ClyPh4QlkWQFdSKPmUmhdA+dGvd5H2FkC8eLaN1JsWQMjmS8cHwxdAa\u002fwNAbYsF0DTL3y6KMUWQLBfOVehJRdAPR3ST7rfFkD1gvD5jzkYQLFUiXWP4hdA+ieHdZaIFkDNF+qk2LwVQMNxAnhOmRdAnYU2JEUgF0AoxT9e4pgXQJWb2LTf4xZA5NWGM3y5FkBGoFazDc8WQMZJAsdKHhdASHOcNz9lF0Divt00VFMXQIZNvdAirhdA6v19pd+CFkBAoODmcFUXQNj6qGgANBZAgaLmmTE0F0B9OH4cG9EXQMAE6NX\u002f8BVA7dkF83JXF0B9uuENergVQN5QEYB7zxZAbs41+P3rFkBaqYNs86IWQMPC+HovwBZA1vbgIA9\u002fFkBY7jOVVwoXQH9\u002ft49LaBZAz5qeLRboFUCACWHBq1YWQMesNATGBxdAjuCk3eD5FkCwobdl9okWQO4QTBFO\u002fBZA82mzn+WrF0CdFNbVtA8WQHBcXe0lARdAM+4nl2o4FkDJ4YimECcXQHnuZFe51xdATh61D+aPFkC4IcUGXF4WQL\u002fe5+6FQxZAEnsOQ3AUGED9dKYzRPwWQAS5mW0zKBdAuPt3evptFkAArEZEBnYXQFa\u002fPvjulBdA8fKls\u002fWRFkATF7+HxDIXQLIKCBkGhRdAYnwEAmSwFkAhrXzx4EEXQDPkNyVISxZAUCnpXJ6qFkCV7GyfzokXQED\\u002fYYRkZ4WQPirqcqhqhdAOQ58D3ZwFkBFjmjJFKIWQGDylNJY5xZArtsU+pwSF0D8X6u+GRcXQLdLfrQ7KBdATnw7qff7FkBwRL\u002fZZwcXQDJnYy2wzxZADcIPPHNLF0D5jYYpPSoXQDddpduKNhdA","shape":"210, 1"},"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eseverity_index_sum=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cbr\u003eseverity_index=%{color}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Dong dat\u002fBrazil","Nang nong cuc doan\u002fBrazil","Bao\u002fIndia","Nang nong cuc doan\u002fIndonesia","Chay rung\u002fUnited States","Lu lut\u002fFrance","Bao bien\u002fGermany","Lu lut\u002fGreece","Han han\u002fSpain","Loc xoay\u002fMexico","Loc xoay\u002fSouth Africa","Han han\u002fGermany","Bao bien\u002fIndia","Sat lo dat\u002fPhilippines","Bao\u002fGreece","Dong dat\u002fMexico","Han han\u002fNigeria","Chay rung\u002fPhilippines","Loc xoay\u002fGreece","Bao\u002fGermany","Lu lut\u002fJapan","Bao bien\u002fCanada","Nang nong cuc doan\u002fPhilippines","Lu l ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="7adc0f64-b54d-49b0-8e84-1319a1bd0c60" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7adc0f64-b54d-49b0-8e84-1319a1bd0c60")) {                    Plotly.newPlot(                        "7adc0f64-b54d-49b0-8e84-1319a1bd0c60",                        [{"hole":0.5,"hovertemplate":"\u003cb\u003e%{label}\u003c\u002fb\u003e\u003cbr\u003eSo luong: %{value:,}\u003cbr\u003eTy le: %{percent}\u003cextra\u003e\u003c\u002fextra\u003e","insidetextorientation":"horizontal","labels":["Sat lo dat","Dong dat","Lu lut","Bao","Nang nong cuc doan","Bao bien","Nui lua","Chay rung","Loc xoay","Han han"],"marker":{"colors":["#FF006E","#FB5607","#FFBE0B","#8338EC","#3A86FF","#06FFA5","#FF6B9D","#C084FC","#60A5FA","#34D399"],"line":{"color":"rgba(17, 17, 27, 1)","width":3}},"pull":[0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02],"textfont":{"color":"white","size":10},"textinfo":"percent+label","textposition":"inside","values":{"dtype":"i2","bdata":"ChTME68TihOJE3wTdxNaE0sTIBM="},"type":"pie"}],                        {"template":{"layout":{"colorway":["#FF6B9D","#C084FC","#60A5FA","#34D399","#FBBF24","#F87171","#A78BFA","#38BDF8","#4ADE80","#FB923C"],"font":{"color":"#E8E8E8","family":"Segoe UI, Arial"},"hoverlabel":{"bgcolor":"rgba(30, 30, 46, 0.95)","font":{"family":"Segoe UI","size":12}},"paper_bgcolor":"rgba(17, 17, 27, 0.95)","plot_bgcolor":"rgba(17, 17, 27, 0.95)","title":{"font":{"color":"#FFFFFF","size":20}}}},"annotations":[{"font":{"color":"#FFFFFF","size":22},"showarrow":false,"text":"\u003cb\u003e50,000\u003c\u002fb\u003e\u003cbr\u003e\u003cspan style='font-size:11px'\u003eSu kien\u003c\u002fspan\u003e","x":0.5,"y":0.5}],"title":{"font":{"size":20,"color":"#FFFFFF"},"text":"TY LE THAM HOA THEO LOAI","x":0.5},"font":{"family":"Segoe UI","color":"#E8E8E8"},"legend":{"font":{"size":10},"orientation":"v","yanchor":"middle","y":0.5,"xanchor":"left","x":1.02,"bgcolor":"rgba(0,0,0,0)"},"margin":{"t":80,"b":40,"l":40,"r":180},"width":700,"height":500,"paper_bgcolor":"rgba(17, 17, 27, 0.95)","showlegend":true},                        {"displayModeBar": false, "responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('7adc0f64-b54d-49b0-8e84-1319a1bd0c60');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %% [markdown]
# ## Ban Do Tham Hoa Toan Cau

# %%
# Ban do tham hoa toan cau
country_stats = df.groupby('country').agg({
    'disaster_type': 'count',
    'casualties': 'sum',
    'economic_loss_usd': 'sum'
}).reset_index()
country_stats.columns = ['country', 'total_events', 'total_casualties', 'total_economic_loss']

fig = px.choropleth(
    country_stats,
    locations='country',
    locationmode='country names',
    color='total_events',
    hover_data={
        'total_events': ':,',
        'total_casualties': ':,.0f',
        'total_economic_loss': ':,.0f'
    },
    title='BAN DO THAM HOA TOAN CAU',
    color_continuous_scale=[
        [0, 'rgba(30, 58, 95, 0.8)'],
        [0.2, 'rgba(52, 152, 219, 0.8)'],
        [0.4, 'rgba(241, 196, 15, 0.8)'],
        [0.6, 'rgba(230, 126, 34, 0.8)'],
        [0.8, 'rgba(231, 76, 60, 0.8)'],
        [1, 'rgba(192, 57, 43, 0.9)']
    ]
)
fig.update_layout(
    width=1000, height=600,
    paper_bgcolor='rgba(17, 17, 27, 0.95)',
    geo=dict(
        showframe=False,
        showcoastlines=True,
        coastlinecolor="rgba(255,255,255,0.2)",
        projection_type='natural earth',
        bgcolor='rgba(17, 17, 27, 0)',
        landcolor='rgba(40, 40, 60, 0.8)',
        showocean=True,
        oceancolor='rgba(15, 23, 42, 0.9)',
        lakecolor='rgba(15, 23, 42, 0.9)',
        showlakes=True,
        showcountries=True,
        countrycolor='rgba(255,255,255,0.1)'
    ),
    font=dict(family="Segoe UI", size=12, color="#E8E8E8"),
    title=dict(font=dict(size=22, color="#FFFFFF"), x=0.5, y=0.95),
    coloraxis_colorbar=dict(
        title=dict(text="So Su Kien", font=dict(color="#E8E8E8")),
        tickfont=dict(color="#E8E8E8"),
        bgcolor='rgba(0,0,0,0.3)',
        bordercolor='rgba(255,255,255,0.1)',
        len=0.6
    ),
    margin=dict(t=80, b=20, l=20, r=20)
)
fig.update_traces(
    hovertemplate='<b>%{location}</b><br>' +
                  'Su kien: %{z:,}<br>' +
                  'Thuong vong: %{customdata[1]:,.0f}<br>' +
                  'Thiet hai: $%{customdata[2]:,.0f}<extra></extra>'
)
fig.show(config={'displayModeBar': False})
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="e8870c39-d3cf-4952-b294-5099386b7073" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e8870c39-d3cf-4952-b294-5099386b7073")) {                    Plotly.newPlot(                        "e8870c39-d3cf-4952-b294-5099386b7073",                        [{"coloraxis":"coloraxis","customdata":{"dtype":"f8","bdata":"AAAAAAAGpEAAAAAAMEgPQaRwy4AfpQdCAAAAAADyo0AAAAAAsKwOQUjhZJ+DQwhCAAAAAAA+pEAAAAAAhA0QQY\u002fCw0kMmQhCAAAAAAAMo0AAAAAAaLwNQa5Hf\...","shape":"20, 3"},"geo":"geo","hovertemplate":"\u003cb\u003e%{location}\u003c\u002fb\u003e\u003cbr\u003eSu kien: %{z:,}\u003cbr\u003eThuong vong: %{customdata[1]:,.0f}\u003cbr\u003eThiet hai: $%{customdata[2]:,.0f}\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"country names","locations":["Australia","Bangladesh","Brazil","Canada","Chile","China","France","Germany","Greece","India","Indonesia","Italy","Japan","Mexico","Nigeria","Philippines","South Africa","Spain","Turkey","United States"],"name":"","z":{"dtype":"i2","bdata":"Awr5CR8KhgnhCesJYgneCccJzQmjCccJqAmBCeAJhQnBCe8J+gltCQ=="},"type":"choropleth"}],                        {"template":{"layout":{"colorway":["#FF6B9D","#C084FC","#60A5FA","#34D399","#FBBF24","#F87171","#A78BFA","#38BDF8","#4ADE80","#FB923C"],"font":{"color":"#E8E8E8","family":"Segoe UI, Arial"},"hoverlabel":{"bgcolor":"rgba(30, 30, 46, 0.95)","font":{"family":"Segoe UI","size":12}},"paper_bgcolor":"rgba(17, 17, 27, 0.95)","plot_bgcolor":"rgba(17, 17, 27, 0.95)","title":{"font":{"color":"#FFFFFF","size":20}}}},"geo":{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"center":{},"projection":{"type":"natural earth"},"showframe":false,"showcoastlines":true,"coastlinecolor":"rgba(255,255,255,0.2)","bgcolor":"rgba(17, 17, 27, 0)","landcolor":"rgba(40, 40, 60, 0.8)","showocean":true,"oceancolor":"rgba(15, 23, 42, 0.9)","lakecolor":"rgba(15, 23, 42, 0.9)","showlakes":true,"showcountries":true,"countrycolor":"rgba(255,255,255,0.1)"},"coloraxis":{"colorbar":{"title":{"text":"So Su Kien","font":{"color":"#E8E8E8"}},"tickfont":{"color":"#E8E8E8"},"bgcolor":"rgba(0,0,0,0.3)","bordercolor":"rgba(255,255,255,0.1)","len":0.6},"colorscale":[[0,"rgba(30, 58, 95, 0.8)"],[0.2,"rgba(52, 152, 219, 0.8)"],[0.4,"rgba(241, 196, 15, 0.8)"],[0.6,"rgba(230, 126, 34, 0.8)"],[0.8,"rgba(231, 76, 60, 0.8)"],[1,"rgba(192, 57, 43, 0.9)"]]},"legend":{"tracegroupgap":0},"title":{"text":"BAN DO THAM HOA TOAN CAU","font":{"size":22,"color":"#FFFFFF"},"x":0.5,"y":0.95},"font":{"family":"Segoe UI","size":12,"color":"#E8E8E8"},"margin":{"t":80,"b":20,"l":20,"r":20},"width":1000,"height":600,"paper_bgcolor":"rgba(17, 17, 27, 0.95)"},                        {"displayModeBar": false, "responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('e8870c39-d3cf-4952-b294-5099386b7073');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %% [markdown]
# ## Xu Huong Tham Hoa Theo Thoi Gian

# %%
# Xu huong tham hoa theo thoi gian
yearly_counts = df.groupby(['year', 'loai_tham_hoa']).size().reset_index(name='count')

# Area chart
fig1 = px.area(
    yearly_counts,
    x='year',
    y='count',
    color='loai_tham_hoa',
    title='XU HUONG THAM HOA THEO NAM (2018-2024)',
    color_discrete_sequence=NEON_COLORS,
    line_shape='spline'
)
fig1.update_layout(
    width=900, height=470,
    paper_bgcolor='rgba(17, 17, 27, 0.95)',
    plot_bgcolor='rgba(17, 17, 27, 0.95)',
    font=dict(family="Segoe UI", size=12, color="#E8E8E8"),
    title=dict(font=dict(size=20, color="#FFFFFF"), x=0.5, y=0.97),
    legend=dict(
        orientation="h", yanchor="bottom", y=-0.25, xanchor="center", x=0.5,
        font=dict(size=9), bgcolor='rgba(0,0,0,0)',
        itemsizing='constant'
    ),
    xaxis=dict(
        title="Nam", showgrid=True, gridcolor='rgba(255,255,255,0.05)',
        tickfont=dict(size=12)
    ),
    yaxis=dict(
        title="So Luong Tham Hoa", showgrid=True, gridcolor='rgba(255,255,255,0.05)',
        tickfont=dict(size=12)
    ),
    hovermode='x unified',
    margin=dict(t=80, b=100)
)
fig1.update_traces(line=dict(width=2), fillcolor='rgba(0,0,0,0)')
fig1.show(config={'displayModeBar': False})

# Tong so theo nam
yearly_total = df.groupby('year').size().reset_index(name='count')
fig2 = go.Figure()
for i, row in yearly_total.iterrows():
    fig2.add_trace(go.Bar(
        x=[row['year']],
        y=[row['count']],
        marker=dict(
            color=f'rgba({100 + i*20}, {150 - i*10}, 255, 0.8)',
            line=dict(color='rgba(255,255,255,0.3)', width=2)
        ),
        text=f"<b>{row['count']:,}</b>",
        textposition='outside',
        textfont=dict(color='#FFFFFF', size=14),
        hovertemplate=f"<b>Nam {row['year']}</b><br>So su kien: {row['count']:,}<extra></extra>",
        showlegend=False
    ))
fig2.update_layout(
    title=dict(text='TONG SO THAM HOA THEO NAM', font=dict(size=20, color='#FFFFFF'), x=0.5),
    width=900, height=500,
    paper_bgcolor='rgba(17, 17, 27, 0.95)',
    plot_bgcolor='rgba(17, 17, 27, 0.95)',
    font=dict(family="Segoe UI", color="#E8E8E8"),
    xaxis=dict(
        title="Nam", showgrid=False, tickfont=dict(size=14, color='#E8E8E8'),
        dtick=1
    ),
    yaxis=dict(
        title="Tong So Su Kien", showgrid=True, gridcolor='rgba(255,255,255,0.05)',
        tickfont=dict(size=12)
    ),
    bargap=0.3,
    margin=dict(t=80, b=60)
)
fig2.show(config={'displayModeBar': False})
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="8a5a423b-ff94-490a-bcf7-40c71156dbcd" class="plotly-graph-div" style="height:470px; width:900px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8a5a423b-ff94-490a-bcf7-40c71156dbcd")) {                    Plotly.newPlot(                        "8a5a423b-ff94-490a-bcf7-40c71156dbcd",                        [{"fillpattern":{"shape":""},"hovertemplate":"loai_tham_hoa=Bao\u003cbr\u003eyear=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bao","line":{"color":"#FF006E","shape":"spline","width":2},"marker":{"symbol":"circle"},"mode":"lines","name":"Bao","orientation":"v","showlegend":true,"stackgroup":"1","x":{"dtype":"i4","bdata":"4gcAAOMHAADkBwAA5QcAAOYHAADnBwAA6AcAAA=="},"xaxis":"x","y":{"dtype":"i2","bdata":"nwKrAuMCEgOjAtUC0wI="},"yaxis":"y","type":"scatter","fillcolor":"rgba(0,0,0,0)"},{"fillpattern":{"shape":""},"hovertemplate":"loai_tham_hoa=Bao bien\u003cbr\u003eyear=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bao bien","line":{"color":"#FB5607","shape":"spline","width":2},"marker":{"symbol":"circle"},"mode":"lines","name":"Bao bien","orientation":"v","showlegend":true,"stackgroup":"1","x":{"dtype":"i4","bdata":"4gcAAOMHAADkBwAA5QcAAOYHAADnBwAA6AcAAA=="},"xaxis":"x","y":{"dtype":"i2","bdata":"swLsAtMCuAK7ArMC5AI="},"yaxis":"y","type":"scatter","fillcolor":"rgba(0,0,0,0)"},{"fillpattern":{"shape":""},"hovertemplate":"loai_tham_hoa=Chay rung\u003cbr\u003eyear=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chay rung","line":{"color":"#FFBE0B","shape":"spline","width":2},"marker":{"symbol":"circle"},"mode":"lines","name":"Chay rung","orientation":"v","showlegend":true,"stackgroup":"1","x":{"dtype":"i4","bdata":"4gcAAOMHAADkBwAA5QcAAOYHAADnBwAA6AcAAA=="},"xaxis":"x","y":{"dtype":"i2","bdata":"rwLhAvQC0wKvAqcCrQI="},"yaxis":"y","type":"scatter","fillcolor":"rgba(0,0,0,0)"},{"fillpattern":{"shape":""},"hovertemplate":"loai_tham_hoa=Dong dat\u003cbr\u003eyear=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Dong dat","line":{"color":"#8338EC","shape":"spline","width":2},"marker":{"symbol":"circle"},"mode":"lines","name":"Dong dat","orientation":"v","showlegend":true,"stackgroup":"1","x":{"dtype":"i4","bdata":"4gcAAOMHAADkBwAA5QcAAOYHAADnBwAA6AcAAA=="},"xaxis":"x","y":{"dtype":"i2","bdata":"vgLUAsMC4gK9AucC8QI="},"yaxis":"y","type":"scatter","fillcolor":"rgba(0,0,0,0)"},{"fillpattern":{"shape":""},"hovertemplate":"loai_tham_hoa=Han han\u003cbr\u003eyear=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Han han","line":{"color":"#3A86FF","shape":"spline","width":2},"marker":{"symbol":"circle"},"mode":"lines","name":"Han han","orientation":"v","showlegend":true,"stackgroup":"1","x":{"dtype":"i4","bdata":"4gcAAOMHAADkBwAA5QcAAOYHAADnBwAA6AcAAA=="},"xaxis":"x","y":{"dtype":"i2","bdata":"0wKbAqgCvgLfAp4CzwI="},"yaxis":"y","type":"scatter","fillcolor":"rgba(0,0,0,0)"},{"fillpattern":{"shape":""},"hovertemplate":"loai_tham_hoa=Loc xoay\u003cbr\u003eyear=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loc xoay","line":{"color":"#06FFA5","shape":"spline","width":2},"marker":{"symbol":"circle"},"mode":"lines","name":"Loc xoay","orientation":"v","showlegend":true,"stackgroup":"1","x":{"dtype":"i4","bdata":"4gcAAOMHAADkBwAA5QcAAOYHAADnBwAA6AcAAA=="},"xaxis":"x","y":{"dtype":"i2","bdata":"twLUAtQCuAKYAtQCyAI="},"yaxis":"y","type":"scatter","fillcolor":"rgba(0,0,0,0)"},{"fillpattern":{"shape":" ...
#
# var gd = document.getElementById('8a5a423b-ff94-490a-bcf7-40c71156dbcd');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContaine
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="2e7f9234-4b38-4a4c-a857-d6b8075856d5" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2e7f9234-4b38-4a4c-a857-d6b8075856d5")) {                    Plotly.newPlot(                        "2e7f9234-4b38-4a4c-a857-d6b8075856d5",                        [{"hovertemplate":"\u003cb\u003eNam 2018\u003c\u002fb\u003e\u003cbr\u003eSo su kien: 7,014\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"rgba(100, 150, 255, 0.8)","line":{"color":"rgba(255,255,255,0.3)","width":2}},"showlegend":false,"text":"\u003cb\u003e7,014\u003c\u002fb\u003e","textfont":{"color":"#FFFFFF","size":14},"textposition":"outside","x":[2018],"y":[7014],"type":"bar"},{"hovertemplate":"\u003cb\u003eNam 2019\u003c\u002fb\u003e\u003cbr\u003eSo su kien: 7,113\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"rgba(120, 140, 255, 0.8)","line":{"color":"rgba(255,255,255,0.3)","width":2}},"showlegend":false,"text":"\u003cb\u003e7,113\u003c\u002fb\u003e","textfont":{"color":"#FFFFFF","size":14},"textposition":"outside","x":[2019],"y":[7113],"type":"bar"},{"hovertemplate":"\u003cb\u003eNam 2020\u003c\u002fb\u003e\u003cbr\u003eSo su kien: 7,247\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"rgba(140, 130, 255, 0.8)","line":{"color":"rgba(255,255,255,0.3)","width":2}},"showlegend":false,"text":"\u003cb\u003e7,247\u003c\u002fb\u003e","textfont":{"color":"#FFFFFF","size":14},"textposition":"outside","x":[2020],"y":[7247],"type":"bar"},{"hovertemplate":"\u003cb\u003eNam 2021\u003c\u002fb\u003e\u003cbr\u003eSo su kien: 7,271\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"rgba(160, 120, 255, 0.8)","line":{"color":"rgba(255,255,255,0.3)","width":2}},"showlegend":false,"text":"\u003cb\u003e7,271\u003c\u002fb\u003e","textfont":{"color":"#FFFFFF","size":14},"textposition":"outside","x":[2021],"y":[7271],"type":"bar"},{"hovertemplate":"\u003cb\u003eNam 2022\u003c\u002fb\u003e\u003cbr\u003eSo su kien: 7,130\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"rgba(180, 110, 255, 0.8)","line":{"color":"rgba(255,255,255,0.3)","width":2}},"showlegend":false,"text":"\u003cb\u003e7,130\u003c\u002fb\u003e","textfont":{"color":"#FFFFFF","size":14},"textposition":"outside","x":[2022],"y":[7130],"type":"bar"},{"hovertemplate":"\u003cb\u003eNam 2023\u003c\u002fb\u003e\u003cbr\u003eSo su kien: 7,139\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"rgba(200, 100, 255, 0.8)","line":{"color":"rgba(255,255,255,0.3)","width":2}},"showlegend":false,"text":"\u003cb\u003e7,139\u003c\u002fb\u003e","textfont":{"color":"#FFFFFF","size":14},"textposition":"outside","x":[2023],"y":[7139],"type":"bar"},{"hovertemplate":"\u003cb\u003eNam 2024\u003c\u002fb\u003e\u003cbr\u003eSo su kien: 7,086\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"rgba(220, 90, 255, 0.8)","line":{"color":"rgba(255,255,255,0.3)","width":2}},"showlegend":false,"text":"\u003cb\u003e7,086\u003c\u002fb\u003e","textfont":{"color":"#FFFFFF","size":14},"textposition":"outside","x":[2024],"y":[7086],"type":"bar"}],                        {"template":{"layout":{"colorway":["#FF6B9D","#C084FC","#60A5FA","#34D399","#FBBF24","#F87171","#A78BFA","#38BDF8","#4ADE80","#FB923C"],"font":{"color":"#E8E8E8","family":"Segoe UI, Arial"},"hoverlabel":{"bgcolor":"rgba(30, 30, 46, 0.95)","font":{"family":"Segoe UI","size":12}},"paper_bgcolor":"rgba(17, 17, 27, 0.95)","plot_bgcolor":"rgba(17, 17, 27, 0.95)","title":{"font":{"color":"#FFFFFF","size":20}}}},"title":{"font":{"size":20,"color":"#FFFFFF"} ...
#
# var gd = document.getElementById('2e7f9234-4b38-4a4c-a857-d6b8075856d5');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %% [markdown]
# ## Thiet Hai Kinh Te va Thuong Vong

# %%
# Thiet hai kinh te va thuong vong
impact_data = df.groupby('loai_tham_hoa').agg({
    'casualties': 'sum',
    'economic_loss_usd': 'sum'
}).reset_index().sort_values('casualties', ascending=True)

fig = make_subplots(
    rows=1, cols=2, 
    subplot_titles=['THUONG VONG', 'THIET HAI KINH TE'],
    specs=[[{"type": "bar"}, {"type": "bar"}]],
    horizontal_spacing=0.13  # tăng khoảng cách giữa 2 biểu đồ
)
fig.add_trace(
    go.Bar(
        y=impact_data['loai_tham_hoa'], 
        x=impact_data['casualties'], 
        orientation='h',
        marker=dict(
            color=impact_data['casualties'],
            colorscale=GRADIENT_SCALES['fire'],
            line=dict(color='rgba(255,255,255,0.2)', width=1)
        ),
        text=[f'{x:,.0f}' for x in impact_data['casualties']],
        textposition='auto',  # tự động chọn vị trí để không bị đè
        textfont=dict(size=12, color='#FFFFFF'),
        insidetextanchor='middle',
        cliponaxis=False,
        hovertemplate='<b>%{y}</b><br>Thuong vong: %{x:,.0f}<extra></extra>'
    ),
    row=1, col=1
)
economic_sorted = impact_data.sort_values('economic_loss_usd', ascending=True)
fig.add_trace(
    go.Bar(
        y=economic_sorted['loai_tham_hoa'], 
        x=economic_sorted['economic_loss_usd']/1e9,
        orientation='h',
        marker=dict(
            color=economic_sorted['economic_loss_usd'],
            colorscale=GRADIENT_SCALES['forest'],
            line=dict(color='rgba(255,255,255,0.2)', width=1)
        ),
        text=[f'${x/1e9:.1f}B' for x in economic_sorted['economic_loss_usd']],
        textposition='auto',
        textfont=dict(size=12, color='#FFFFFF'),
        insidetextanchor='middle',
        cliponaxis=False,
        hovertemplate='<b>%{y}</b><br>Thiet hai: $%{x:.1f}B<extra></extra>'
    ),
    row=1, col=2
)
fig.update_layout(
    width=1200, height=420,  # tăng chiều rộng và chiều cao
    title_text='THIET HAI KINH TE VA THUONG VONG THEO LOAI THAM HOA',
    paper_bgcolor='rgba(17, 17, 27, 0.95)',
    plot_bgcolor='rgba(17, 17, 27, 0.95)',
    font=dict(family="Segoe UI", size=13, color="#E8E8E8"),
    title=dict(font=dict(size=20, color='#FFFFFF'), x=0.5, y=0.97),
    showlegend=False,
    margin=dict(t=100, b=40, l=180, r=120)
)
for annotation in fig['layout']['annotations']:
    annotation['font'] = dict(size=15, color='#FFFFFF')
fig.update_xaxes(showgrid=True, gridcolor='rgba(255,255,255,0.05)', tickfont=dict(color='#E8E8E8'))
fig.update_yaxes(tickfont=dict(size=12, color='#E8E8E8'))
fig.show(config={'displayModeBar': False})
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="6f9fb760-a4e1-492c-a4ff-0fdf46387c38" class="plotly-graph-div" style="height:420px; width:1200px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6f9fb760-a4e1-492c-a4ff-0fdf46387c38")) {                    Plotly.newPlot(                        "6f9fb760-a4e1-492c-a4ff-0fdf46387c38",                        [{"cliponaxis":false,"hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eThuong vong: %{x:,.0f}\u003cextra\u003e\u003c\u002fextra\u003e","insidetextanchor":"middle","marker":{"color":{"dtype":"i4","bdata":"YoAHAFeYBwAepQcAxKYHADOnBwCergcA4rMHAPu0BwDNuwcAn98HAA=="},"colorscale":[[0,"#1a1a2e"],[0.25,"#e94560"],[0.5,"#ff6b6b"],[0.75,"#feca57"],[1,"#fff200"]],"line":{"color":"rgba(255,255,255,0.2)","width":1}},"orientation":"h","text":["491,618","497,751","501,022","501,444","501,555","503,454","504,802","505,083","506,829","515,999"],"textfont":{"color":"#FFFFFF","size":12},"textposition":"auto","x":{"dtype":"i4","bdata":"YoAHAFeYBwAepQcAxKYHADOnBwCergcA4rMHAPu0BwDNuwcAn98HAA=="},"y":["Han han","Nang nong cuc doan","Nui lua","Chay rung","Bao","Lu lut","Loc xoay","Bao bien","Dong dat","Sat lo dat"],"type":"bar","xaxis":"x","yaxis":"y"},{"cliponaxis":false,"hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eThiet hai: $%{x:.1f}B\u003cextra\u003e\u003c\u002fextra\u003e","insidetextanchor":"middle","marker":{"color":{"dtype":"f8","bdata":"Urjn822sFkJI4cjGw00XQrgeev1BlxdCCteX0NCdF0L2KKPKEKUXQoXrq1DLrxdC9ihUb0O1F0IpXG1ur70XQtejeVEZ\u002fBdCcT0o1CoTGEI="},"colorscale":[[0,"#1a1a2e"],[0.25,"#155d27"],[0.5,"#2d6a4f"],[0.75,"#40916c"],[1,"#95d5b2"]],"line":{"color":"rgba(255,255,255,0.2)","width":1}},"orientation":"h","text":["$24.3B","$25.0B","$25.3B","$25.4B","$25.4B","$25.4B","$25.5B","$25.5B","$25.8B","$25.9B"],"textfont":{"color":"#FFFFFF","size":12},"textposition":"auto","x":{"dtype":"f8","bdata":"o0nKbnVYOECKsaftsAU5QHpeUomaVDlAyD8iKaVbOUCJVCIAbmM5QDnjyA7zbjlASLjFbNJ0OUDnWJJo3X05QFOLrojhwDlAPoQKh6bZOUA="},"y":["Han han","Chay rung","Bao","Lu lut","Bao bien","Nang nong cuc doan","Loc xoay","Dong dat","Sat lo dat","Nui lua"],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"layout":{"colorway":["#FF6B9D","#C084FC","#60A5FA","#34D399","#FBBF24","#F87171","#A78BFA","#38BDF8","#4ADE80","#FB923C"],"font":{"color":"#E8E8E8","family":"Segoe UI, Arial"},"hoverlabel":{"bgcolor":"rgba(30, 30, 46, 0.95)","font":{"family":"Segoe UI","size":12}},"paper_bgcolor":"rgba(17, 17, 27, 0.95)","plot_bgcolor":"rgba(17, 17, 27, 0.95)","title":{"font":{"color":"#FFFFFF","size":20}}}},"xaxis":{"anchor":"y","domain":[0.0,0.435],"tickfont":{"color":"#E8E8E8"},"showgrid":true,"gridcolor":"rgba(255,255,255,0.05)"},"yaxis":{"anchor":"x","domain":[0.0,1.0],"tickfont":{"size":12,"color":"#E8E8E8"}},"xaxis2":{"anchor":"y2","domain":[0.565,1.0],"tickfont":{"color":"#E8E8E8"},"showgrid":true,"gridcolor":"rgba(255,255,255,0.05)"},"yaxis2":{"anchor":"x2","domain":[0.0,1.0],"tickfont":{"size":12,"color":"#E8E8E8"}},"annotations":[{"font":{"color":"#FFFFFF","size":15},"showarrow":false,"text":"THUONG VONG","x":0.2175,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"color":"#FFFFFF","size":15},"showarrow":false,"text":"THIET HAI KINH TE","x":0.7825,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"}],"title":{"font":{"size":20,"color":"#FFFFFF"},"text":"THIET HAI KINH TE VA THUONG VONG THEO LOAI THAM HOA","x":0.5,"y":0.97},"font":{"family":"Segoe UI","size":13,"color":"#E8E8E8"},"margin":{"t":100,"b":40,"l":180,"r":12 ...
#
# var gd = document.getElementById('6f9fb760-a4e1-492c-a4ff-0fdf46387c38');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %% [markdown]
# ## Top 10 Quoc Gia Bi Anh Huong Nhieu Nhat

# %%
# Top 10 quoc gia
# Treemap
# Tinh toan top 10 quoc gia co nhieu tham hoa nhat
# ...
top_countries = df.groupby('country').agg({
    'disaster_type': 'count',
    'casualties': 'sum'
}).reset_index()
top_countries.columns = ['country', 'total_events', 'total_casualties']
top_countries = top_countries.nlargest(10, 'total_events')

# Modern Treemap with custom colors
fig1 = px.treemap(
    top_countries,
    path=['country'],
    values='total_events',
    color='total_events',
    color_continuous_scale=GRADIENT_SCALES['purple'],
    title='TOP 10 QUOC GIA CO NHIEU THAM HOA NHAT'
)
fig1.update_layout(
    width=900, height=550,
    paper_bgcolor='rgba(17, 17, 27, 0.95)',
    font=dict(family="Segoe UI", size=14, color="#FFFFFF"),
    title=dict(font=dict(size=20, color='#FFFFFF'), x=0.5, y=0.97),
    margin=dict(t=80, b=20, l=20, r=20),
    coloraxis_showscale=False
)
fig1.update_traces(
    textinfo='label+value',
    textfont=dict(size=16, color='white'),
    marker=dict(line=dict(color='rgba(255,255,255,0.3)', width=2)),
    hovertemplate='<b>%{label}</b><br>So su kien: %{value:,}<extra></extra>'
)
fig1.show(config={'displayModeBar': False})

# Horizontal bar chart
# Top 10 quoc gia co thuong vong cao nhat
# ...
top_casualties = df.groupby('country')['casualties'].sum().nlargest(10).reset_index()
top_casualties = top_casualties.sort_values('casualties', ascending=True)

fig2 = go.Figure()
colors_gradient = [f'rgba({255 - i*15}, {100 + i*10}, {150 + i*8}, 0.85)' for i in range(len(top_casualties))]
fig2.add_trace(go.Bar(
    x=top_casualties['casualties'],
    y=top_casualties['country'],
    orientation='h',
    marker=dict(
        color=colors_gradient,
        line=dict(color='rgba(255,255,255,0.4)', width=2)
    ),
    text=[f'<b>{x:,.0f}</b>' for x in top_casualties['casualties']],
    textposition='outside',
    textfont=dict(color='#FFFFFF', size=11),
    hovertemplate='<b>%{y}</b><br>Thuong vong: %{x:,.0f}<extra></extra>'
))
fig2.update_layout(
    title=dict(text='TOP 10 QUOC GIA CO THUONG VONG CAO NHAT', font=dict(size=20, color='#FFFFFF'), x=0.5),
    width=900, height=550,
    paper_bgcolor='rgba(17, 17, 27, 0.95)',
    plot_bgcolor='rgba(17, 17, 27, 0.95)',
    font=dict(family="Segoe UI", size=12, color="#E8E8E8"),
    xaxis=dict(
        title='So Thuong Vong', showgrid=True, gridcolor='rgba(255,255,255,0.05)',
        tickfont=dict(size=11)
    ),
    yaxis=dict(title='', tickfont=dict(size=12)),
    margin=dict(t=80, b=60, l=120, r=80)
)
fig2.show(config={'displayModeBar': False})
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="c8b277ee-72b2-487e-bffa-162e2cf79b0b" class="plotly-graph-div" style="height:550px; width:900px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c8b277ee-72b2-487e-bffa-162e2cf79b0b")) {                    Plotly.newPlot(                        "c8b277ee-72b2-487e-bffa-162e2cf79b0b",                        [{"branchvalues":"total","customdata":{"dtype":"f8","bdata":"AAAAAAA+pEAAAAAAAAakQAAAAAAA9KNAAAAAAADyo0AAAAAAAN6jQAAAAAAA1qNAAAAAAADCo0AAAAAAAMCjQAAAAAAAvKNAAAAAAACao0A=","shape":"10, 1"},"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"\u003cb\u003e%{label}\u003c\u002fb\u003e\u003cbr\u003eSo su kien: %{value:,}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Brazil","Australia","Turkey","Bangladesh","Spain","China","Chile","Nigeria","Germany","India"],"labels":["Brazil","Australia","Turkey","Bangladesh","Spain","China","Chile","Nigeria","Germany","India"],"marker":{"coloraxis":"coloraxis","colors":{"dtype":"f8","bdata":"AAAAAAA+pEAAAAAAAAakQAAAAAAA9KNAAAAAAADyo0AAAAAAAN6jQAAAAAAA1qNAAAAAAADCo0AAAAAAAMCjQAAAAAAAvKNAAAAAAACao0A="},"line":{"color":"rgba(255,255,255,0.3)","width":2}},"name":"","parents":["","","","","","","","","",""],"values":{"dtype":"f8","bdata":"AAAAAAA+pEAAAAAAAAakQAAAAAAA9KNAAAAAAADyo0AAAAAAAN6jQAAAAAAA1qNAAAAAAADCo0AAAAAAAMCjQAAAAAAAvKNAAAAAAACao0A="},"type":"treemap","textfont":{"color":"white","size":16},"textinfo":"label+value"}],                        {"template":{"layout":{"colorway":["#FF6B9D","#C084FC","#60A5FA","#34D399","#FBBF24","#F87171","#A78BFA","#38BDF8","#4ADE80","#FB923C"],"font":{"color":"#E8E8E8","family":"Segoe UI, Arial"},"hoverlabel":{"bgcolor":"rgba(30, 30, 46, 0.95)","font":{"family":"Segoe UI","size":12}},"paper_bgcolor":"rgba(17, 17, 27, 0.95)","plot_bgcolor":"rgba(17, 17, 27, 0.95)","title":{"font":{"color":"#FFFFFF","size":20}}}},"coloraxis":{"colorbar":{"title":{"text":"total_events"}},"colorscale":[[0,"#1a1a2e"],[0.25,"#4a1a6b"],[0.5,"#7c3aed"],[0.75,"#a78bfa"],[1,"#ddd6fe"]],"showscale":false},"legend":{"tracegroupgap":0},"title":{"text":"TOP 10 QUOC GIA CO NHIEU THAM HOA NHAT","font":{"size":20,"color":"#FFFFFF"},"x":0.5,"y":0.97},"font":{"family":"Segoe UI","size":14,"color":"#FFFFFF"},"margin":{"t":80,"b":20,"l":20,"r":20},"width":900,"height":550,"paper_bgcolor":"rgba(17, 17, 27, 0.95)"},                        {"displayModeBar": false, "responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('c8b277ee-72b2-487e-bffa-162e2cf79b0b');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="09403b18-a2de-452f-bb92-95eacbb82a27" class="plotly-graph-div" style="height:550px; width:900px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("09403b18-a2de-452f-bb92-95eacbb82a27")) {                    Plotly.newPlot(                        "09403b18-a2de-452f-bb92-95eacbb82a27",                        [{"hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eThuong vong: %{x:,.0f}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":["rgba(255, 100, 150, 0.85)","rgba(240, 110, 158, 0.85)","rgba(225, 120, 166, 0.85)","rgba(210, 130, 174, 0.85)","rgba(195, 140, 182, 0.85)","rgba(180, 150, 190, 0.85)","rgba(165, 160, 198, 0.85)","rgba(150, 170, 206, 0.85)","rgba(135, 180, 214, 0.85)","rgba(120, 190, 222, 0.85)"],"line":{"color":"rgba(255,255,255,0.4)","width":2}},"orientation":"h","text":["\u003cb\u003e252,096\u003c\u002fb\u003e","\u003cb\u003e252,338\u003c\u002fb\u003e","\u003cb\u003e253,800\u003c\u002fb\u003e","\u003cb\u003e254,200\u003c\u002fb\u003e","\u003cb\u003e254,897\u003c\u002fb\u003e","\u003cb\u003e255,250\u003c\u002fb\u003e","\u003cb\u003e256,262\u003c\u002fb\u003e","\u003cb\u003e256,788\u003c\u002fb\u003e","\u003cb\u003e258,691\u003c\u002fb\u003e","\u003cb\u003e263,009\u003c\u002fb\u003e"],"textfont":{"color":"#FFFFFF","size":11},"textposition":"outside","x":{"dtype":"i4","bdata":"wNgDALLZAwBo3wMA+OADALHjAwAS5QMABukDABTrAwCD8gMAYQMEAA=="},"y":["Chile","India","Greece","Germany","Nigeria","South Africa","Australia","China","Turkey","Brazil"],"type":"bar"}],                        {"template":{"layout":{"colorway":["#FF6B9D","#C084FC","#60A5FA","#34D399","#FBBF24","#F87171","#A78BFA","#38BDF8","#4ADE80","#FB923C"],"font":{"color":"#E8E8E8","family":"Segoe UI, Arial"},"hoverlabel":{"bgcolor":"rgba(30, 30, 46, 0.95)","font":{"family":"Segoe UI","size":12}},"paper_bgcolor":"rgba(17, 17, 27, 0.95)","plot_bgcolor":"rgba(17, 17, 27, 0.95)","title":{"font":{"color":"#FFFFFF","size":20}}}},"title":{"font":{"size":20,"color":"#FFFFFF"},"text":"TOP 10 QUOC GIA CO THUONG VONG CAO NHAT","x":0.5},"font":{"family":"Segoe UI","size":12,"color":"#E8E8E8"},"xaxis":{"tickfont":{"size":11},"title":{"text":"So Thuong Vong"},"showgrid":true,"gridcolor":"rgba(255,255,255,0.05)"},"yaxis":{"tickfont":{"size":12},"title":{"text":""}},"margin":{"t":80,"b":60,"l":120,"r":80},"width":900,"height":550,"paper_bgcolor":"rgba(17, 17, 27, 0.95)","plot_bgcolor":"rgba(17, 17, 27, 0.95)"},                        {"displayModeBar": false, "responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('09403b18-a2de-452f-bb92-95eacbb82a27');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %% [markdown]
# ## Hieu Qua Ung Pho va Hoi Phuc

# %%
# Hieu qua ung pho
response_data = df.groupby('loai_tham_hoa').agg({
    'response_time_hours': 'mean',
    'recovery_days': 'mean'
}).reset_index()

# Polar bar for response time
fig1 = go.Figure()
fig1.add_trace(go.Barpolar(
    r=response_data['response_time_hours'],
    theta=response_data['loai_tham_hoa'],
    marker=dict(
        color=response_data['response_time_hours'],
        colorscale=GRADIENT_SCALES['ocean'],
        line=dict(color='rgba(255,255,255,0.5)', width=2)
    ),
    hovertemplate='<b>%{theta}</b><br>Thoi gian: %{r:.1f} gio<extra></extra>'
))
fig1.update_layout(
    title=dict(text='THOI GIAN PHAN UNG TRUNG BINH (GIO)', font=dict(size=18, color='#FFFFFF'), x=0.5),
    width=700, height=500,
    paper_bgcolor='rgba(17, 17, 27, 0.95)',
    font=dict(family="Segoe UI", size=11, color="#E8E8E8"),
    polar=dict(
        bgcolor='rgba(17, 17, 27, 0.5)',
        angularaxis=dict(
            tickfont=dict(size=9, color='#E8E8E8'),
            gridcolor='rgba(255,255,255,0.1)',
            linecolor='rgba(255,255,255,0.2)'
        ),
        radialaxis=dict(
            tickfont=dict(color='#E8E8E8', size=10),
            gridcolor='rgba(255,255,255,0.1)',
            linecolor='rgba(255,255,255,0.2)'
        )
    ),
    margin=dict(t=80, b=40)
)
fig1.show(config={'displayModeBar': False})

# Polar bar for recovery days
fig2 = go.Figure()
fig2.add_trace(go.Barpolar(
    r=response_data['recovery_days'],
    theta=response_data['loai_tham_hoa'],
    marker=dict(
        color=response_data['recovery_days'],
        colorscale=GRADIENT_SCALES['forest'],
        line=dict(color='rgba(255,255,255,0.5)', width=2)
    ),
    hovertemplate='<b>%{theta}</b><br>Hoi phuc: %{r:.0f} ngay<extra></extra>'
))
fig2.update_layout(
    title=dict(text='THOI GIAN HOI PHUC TRUNG BINH (NGAY)', font=dict(size=18, color='#FFFFFF'), x=0.5),
    width=700, height=500,
    paper_bgcolor='rgba(17, 17, 27, 0.95)',
    font=dict(family="Segoe UI", size=11, color="#E8E8E8"),
    polar=dict(
        bgcolor='rgba(17, 17, 27, 0.5)',
        angularaxis=dict(
            tickfont=dict(size=9, color='#E8E8E8'),
            gridcolor='rgba(255,255,255,0.1)',
            linecolor='rgba(255,255,255,0.2)'
        ),
        radialaxis=dict(
            tickfont=dict(color='#E8E8E8', size=10),
            gridcolor='rgba(255,255,255,0.1)',
            linecolor='rgba(255,255,255,0.2)'
        )
    ),
    margin=dict(t=80, b=40)
)
fig2.show(config={'displayModeBar': False})
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="392f8b6b-e66c-4ee1-bec3-5c5f816e216c" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("392f8b6b-e66c-4ee1-bec3-5c5f816e216c")) {                    Plotly.newPlot(                        "392f8b6b-e66c-4ee1-bec3-5c5f816e216c",                        [{"hovertemplate":"\u003cb\u003e%{theta}\u003c\u002fb\u003e\u003cbr\u003eThoi gian: %{r:.1f} gio\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":{"dtype":"f8","bdata":"e6piNmEVKEAXJINyQTIoQC\u002fFFswIMChAITSKXHKuKECAxAhNkXkoQCbgkGkZBShAAJwu2AXcKEBCh\u002fjgccAoQOVpivtF5ydAmzejPEd8KEA="},"colorscale":[[0,"#0c1445"],[0.25,"#1e3a5f"],[0.5,"#3498db"],[0.75,"#5dade2"],[1,"#85c1e9"]],"line":{"color":"rgba(255,255,255,0.5)","width":2}},"r":{"dtype":"f8","bdata":"e6piNmEVKEAXJINyQTIoQC\u002fFFswIMChAITSKXHKuKECAxAhNkXkoQCbgkGkZBShAAJwu2AXcKEBCh\u002fjgccAoQOVpivtF5ydAmzejPEd8KEA="},"theta":["Bao","Bao bien","Chay rung","Dong dat","Han han","Loc xoay","Lu lut","Nang nong cuc doan","Nui lua","Sat lo dat"],"type":"barpolar"}],                        {"template":{"layout":{"colorway":["#FF6B9D","#C084FC","#60A5FA","#34D399","#FBBF24","#F87171","#A78BFA","#38BDF8","#4ADE80","#FB923C"],"font":{"color":"#E8E8E8","family":"Segoe UI, Arial"},"hoverlabel":{"bgcolor":"rgba(30, 30, 46, 0.95)","font":{"family":"Segoe UI","size":12}},"paper_bgcolor":"rgba(17, 17, 27, 0.95)","plot_bgcolor":"rgba(17, 17, 27, 0.95)","title":{"font":{"color":"#FFFFFF","size":20}}}},"title":{"font":{"size":18,"color":"#FFFFFF"},"text":"THOI GIAN PHAN UNG TRUNG BINH (GIO)","x":0.5},"font":{"family":"Segoe UI","size":11,"color":"#E8E8E8"},"polar":{"angularaxis":{"tickfont":{"size":9,"color":"#E8E8E8"},"gridcolor":"rgba(255,255,255,0.1)","linecolor":"rgba(255,255,255,0.2)"},"radialaxis":{"tickfont":{"color":"#E8E8E8","size":10},"gridcolor":"rgba(255,255,255,0.1)","linecolor":"rgba(255,255,255,0.2)"},"bgcolor":"rgba(17, 17, 27, 0.5)"},"margin":{"t":80,"b":40},"width":700,"height":500,"paper_bgcolor":"rgba(17, 17, 27, 0.95)"},                        {"displayModeBar": false, "responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('392f8b6b-e66c-4ee1-bec3-5c5f816e216c');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="e192e0b6-21b2-4a72-81cd-abccbb842a1b" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e192e0b6-21b2-4a72-81cd-abccbb842a1b")) {                    Plotly.newPlot(                        "e192e0b6-21b2-4a72-81cd-abccbb842a1b",                        [{"hovertemplate":"\u003cb\u003e%{theta}\u003c\u002fb\u003e\u003cbr\u003eHoi phuc: %{r:.0f} ngay\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":{"dtype":"f8","bdata":"fn2+f6DgSEBo2cN6lt1IQPlky5CDA0lAADu0bAKcSEDs6+vr64tIQHCfdOJtKElAyE2L1s+LSEDXoGq16M5IQIlEBioiEUlAytLA5JzsSEA="},"colorscale":[[0,"#1a1a2e"],[0.25,"#155d27"],[0.5,"#2d6a4f"],[0.75,"#40916c"],[1,"#95d5b2"]],"line":{"color":"rgba(255,255,255,0.5)","width":2}},"r":{"dtype":"f8","bdata":"fn2+f6DgSEBo2cN6lt1IQPlky5CDA0lAADu0bAKcSEDs6+vr64tIQHCfdOJtKElAyE2L1s+LSEDXoGq16M5IQIlEBioiEUlAytLA5JzsSEA="},"theta":["Bao","Bao bien","Chay rung","Dong dat","Han han","Loc xoay","Lu lut","Nang nong cuc doan","Nui lua","Sat lo dat"],"type":"barpolar"}],                        {"template":{"layout":{"colorway":["#FF6B9D","#C084FC","#60A5FA","#34D399","#FBBF24","#F87171","#A78BFA","#38BDF8","#4ADE80","#FB923C"],"font":{"color":"#E8E8E8","family":"Segoe UI, Arial"},"hoverlabel":{"bgcolor":"rgba(30, 30, 46, 0.95)","font":{"family":"Segoe UI","size":12}},"paper_bgcolor":"rgba(17, 17, 27, 0.95)","plot_bgcolor":"rgba(17, 17, 27, 0.95)","title":{"font":{"color":"#FFFFFF","size":20}}}},"title":{"font":{"size":18,"color":"#FFFFFF"},"text":"THOI GIAN HOI PHUC TRUNG BINH (NGAY)","x":0.5},"font":{"family":"Segoe UI","size":11,"color":"#E8E8E8"},"polar":{"angularaxis":{"tickfont":{"size":9,"color":"#E8E8E8"},"gridcolor":"rgba(255,255,255,0.1)","linecolor":"rgba(255,255,255,0.2)"},"radialaxis":{"tickfont":{"color":"#E8E8E8","size":10},"gridcolor":"rgba(255,255,255,0.1)","linecolor":"rgba(255,255,255,0.2)"},"bgcolor":"rgba(17, 17, 27, 0.5)"},"margin":{"t":80,"b":40},"width":700,"height":500,"paper_bgcolor":"rgba(17, 17, 27, 0.95)"},                        {"displayModeBar": false, "responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('e192e0b6-21b2-4a72-81cd-abccbb842a1b');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %% [markdown]
# ## Heatmap: Tham Hoa Theo Thang va Loai

# %%
# Heatmap tham hoa theo thang va loai
monthly_disaster = df.groupby(['ten_thang', 'loai_tham_hoa']).size().reset_index(name='count')
heatmap_data = monthly_disaster.pivot(index='loai_tham_hoa', columns='ten_thang', values='count').fillna(0)

month_order = ['Th1', 'Th2', 'Th3', 'Th4', 'Th5', 'Th6', 'Th7', 'Th8', 'Th9', 'Th10', 'Th11', 'Th12']
heatmap_data = heatmap_data.reindex(columns=month_order)

fig = go.Figure(data=go.Heatmap(
    z=heatmap_data.values,
    x=heatmap_data.columns,
    y=heatmap_data.index,
    colorscale=[
        [0, 'rgba(17, 17, 27, 1)'],
        [0.2, 'rgba(88, 28, 135, 0.8)'],
        [0.4, 'rgba(168, 85, 247, 0.8)'],
        [0.6, 'rgba(251, 146, 60, 0.8)'],
        [0.8, 'rgba(239, 68, 68, 0.9)'],
        [1, 'rgba(220, 38, 38, 1)']
    ],
    text=heatmap_data.values.astype(int),
    texttemplate='<b>%{text}</b>',
    textfont=dict(size=10, color='white'),
    hovertemplate='<b>%{y}</b><br>Thang: %{x}<br>So luong: %{z:,.0f}<extra></extra>',
    colorbar=dict(
        title=dict(text='So Luong', font=dict(color='#E8E8E8')),
        tickfont=dict(color='#E8E8E8'),
        bgcolor='rgba(0,0,0,0.3)',
        len=0.7
    )
))
fig.update_layout(
    title=dict(text='HEATMAP: THAM HOA THEO THANG VA LOAI', font=dict(size=20, color='#FFFFFF'), x=0.5),
    width=1000, height=600,
    paper_bgcolor='rgba(17, 17, 27, 0.95)',
    plot_bgcolor='rgba(17, 17, 27, 0.95)',
    font=dict(family="Segoe UI", size=12, color="#E8E8E8"),
    xaxis=dict(
        title='Thang', tickangle=0, tickfont=dict(size=12, color='#E8E8E8'),
        side='bottom'
    ),
    yaxis=dict(
        title='Loai Tham Hoa', tickfont=dict(size=10, color='#E8E8E8')
    ),
    margin=dict(t=80, b=60, l=150, r=80)
)
fig.show(config={'displayModeBar': False})
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="f0c5350e-1a83-40bb-97c9-2b5919fa9080" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f0c5350e-1a83-40bb-97c9-2b5919fa9080")) {                    Plotly.newPlot(                        "f0c5350e-1a83-40bb-97c9-2b5919fa9080",                        [{"colorbar":{"bgcolor":"rgba(0,0,0,0.3)","len":0.7,"tickfont":{"color":"#E8E8E8"},"title":{"font":{"color":"#E8E8E8"},"text":"So Luong"}},"colorscale":[[0,"rgba(17, 17, 27, 1)"],[0.2,"rgba(88, 28, 135, 0.8)"],[0.4,"rgba(168, 85, 247, 0.8)"],[0.6,"rgba(251, 146, 60, 0.8)"],[0.8,"rgba(239, 68, 68, 0.9)"],[1,"rgba(220, 38, 38, 1)"]],"hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eThang: %{x}\u003cbr\u003eSo luong: %{z:,.0f}\u003cextra\u003e\u003c\u002fextra\u003e","text":{"dtype":"i2","bdata":"","shape":"10, 12"},"textfont":{"color":"white","size":10},"texttemplate":"\u003cb\u003e%{text}\u003c\u002fb\u003e","x":["Th1","Th2","Th3","Th4","Th5","Th6","Th7","Th8","Th9","Th10","Th11","Th12"],"y":["Bao","Bao bien","Chay rung","Dong dat","Han han","Loc xoay","Lu lut","Nang nong cuc doan","Nui lua","Sat lo dat"],"z":{"dtype":"i2","bdata":"","shape":"10, 12"},"type":"heatmap"}],                        {"template":{"layout":{"colorway":["#FF6B9D","#C084FC","#60A5FA","#34D399","#FBBF24","#F87171","#A78BFA","#38BDF8","#4ADE80","#FB923C"],"font":{"color":"#E8E8E8","family":"Segoe UI, Arial"},"hoverlabel":{"bgcolor":"rgba(30, 30, 46, 0.95)","font":{"family":"Segoe UI","size":12}},"paper_bgcolor":"rgba(17, 17, 27, 0.95)","plot_bgcolor":"rgba(17, 17, 27, 0.95)","title":{"font":{"color":"#FFFFFF","size":20}}}},"title":{"font":{"size":20,"color":"#FFFFFF"},"text":"HEATMAP: THAM HOA THEO THANG VA LOAI","x":0.5},"font":{"family":"Segoe UI","size":12,"color":"#E8E8E8"},"xaxis":{"tickfont":{"size":12,"color":"#E8E8E8"},"title":{"text":"Thang"},"tickangle":0,"side":"bottom"},"yaxis":{"tickfont":{"size":10,"color":"#E8E8E8"},"title":{"text":"Loai Tham Hoa"}},"margin":{"t":80,"b":60,"l":150,"r":80},"width":1000,"height":600,"paper_bgcolor":"rgba(17, 17, 27, 0.95)","plot_bgcolor":"rgba(17, 17, 27, 0.95)"},                        {"displayModeBar": false, "responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('f0c5350e-1a83-40bb-97c9-2b5919fa9080');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %% [markdown]
# ## Dashboard Tong Quan

# %%
# Dashboard tong quan - PREMIUM GLASSMORPHISM DESIGN
from IPython.display import HTML, display

# Calculate metrics
most_common_disaster = df['loai_tham_hoa'].value_counts().index[0]
most_affected_country = df['country'].value_counts().index[0]
peak_year = df['year'].value_counts().index[0]
avg_response = df['response_time_hours'].mean()
avg_recovery = df['recovery_days'].mean()

html_dashboard = f"""
<style>
    @import url('https://fonts.googleapis.com/css2?family=Inter:wght@300;400;600;700&display=swap');
    
    .dashboard-container {{
        background: linear-gradient(135deg, #0f0f1a 0%, #1a1a2e 50%, #16213e 100%);
        padding: 40px;
        border-radius: 24px;
        font-family: 'Inter', 'Segoe UI', sans-serif;
        position: relative;
        overflow: hidden;
    }}
    
    .dashboard-container::before {{
        content: '';
        position: absolute;
        top: -50%;
        left: -50%;
        width: 200%;
        height: 200%;
        background: radial-gradient(circle, rgba(139, 92, 246, 0.1) 0%, transparent 50%);
        animation: pulse 8s ease-in-out infinite;
    }}
    
    @keyframes pulse {{
        0%, 100% {{ transform: scale(1); opacity: 0.5; }}
        50% {{ transform: scale(1.1); opacity: 0.8; }}
    }}
    
    .dashboard-title {{
        text-align: center;
        font-size: 28px;
        font-weight: 700;
        background: linear-gradient(90deg, #60A5FA, #A78BFA, #F472B6);
        -webkit-background-clip: text;
        -webkit-text-fill-color: transparent;
        margin-bottom: 30px;
        position: relative;
        z-index: 1;
    }}
    
    .metrics-grid {{
        display: grid;
        grid-template-columns: repeat(4, 1fr);
        gap: 20px;
        margin-bottom: 30px;
        position: relative;
        z-index: 1;
    }}
    
    .metric-card {{
        background: rgba(255, 255, 255, 0.05);
        backdrop-filter: blur(10px);
        border: 1px solid rgba(255, 255, 255, 0.1);
        border-radius: 16px;
        padding: 24px;
        text-align: center;
        transition: all 0.3s ease;
    }}
    
    .metric-card:hover {{
        transform: translateY(-5px);
        box-shadow: 0 20px 40px rgba(0, 0, 0, 0.3);
        border-color: rgba(255, 255, 255, 0.2);
    }}
    
    .metric-icon {{
        font-size: 32px;
        margin-bottom: 10px;
    }}
    
    .metric-value {{
        font-size: 32px;
        font-weight: 700;
        margin: 8px 0;
    }}
    
    .metric-label {{
        font-size: 12px;
        color: rgba(255, 255, 255, 0.6);
        text-transform: uppercase;
        letter-spacing: 1px;
    }}
    
    .card-events {{ border-top: 3px solid #F87171; }}
    .card-events .metric-value {{ color: #F87171; }}
    
    .card-countries {{ border-top: 3px solid #34D399; }}
    .card-countries .metric-value {{ color: #34D399; }}
    
    .card-casualties {{ border-top: 3px solid #FBBF24; }}
    .card-casualties .metric-value {{ color: #FBBF24; }}
    
    .card-economic {{ border-top: 3px solid #A78BFA; }}
    .card-economic .metric-value {{ color: #A78BFA; }}
    
    .insights-section {{
        display: grid;
        grid-template-columns: repeat(3, 1fr);
        gap: 16px;
        position: relative;
        z-index: 1;
    }}
    
    .insight-card {{
        background: linear-gradient(135deg, rgba(99, 102, 241, 0.1), rgba(168, 85, 247, 0.1));
        border-radius: 12px;
        padding: 16px 20px;
        display: flex;
        align-items: center;
        gap: 12px;
        border: 1px solid rgba(255, 255, 255, 0.05);
    }}
    
    .insight-icon {{
        font-size: 24px;
    }}
    
    .insight-text {{
        flex: 1;
    }}
    
    .insight-label {{
        font-size: 11px;
        color: rgba(255, 255, 255, 0.5);
        text-transform: uppercase;
    }}
    
    .insight-value {{
        font-size: 14px;
        color: #FFFFFF;
        font-weight: 600;
    }}
    
    .footer-stats {{
        display: flex;
        justify-content: center;
        gap: 40px;
        margin-top: 25px;
        padding-top: 20px;
        border-top: 1px solid rgba(255, 255, 255, 0.1);
        position: relative;
        z-index: 1;
    }}
    
    .footer-stat {{
        text-align: center;
    }}
    
    .footer-value {{
        font-size: 20px;
        font-weight: 600;
        color: #60A5FA;
    }}
    
    .footer-label {{
        font-size: 11px;
        color: rgba(255, 255, 255, 0.5);
    }}
</style>

<div class="dashboard-container">
    <h1 class="dashboard-title">📊 TONG QUAN DU LIEU THAM HOA TOAN CAU 2018-2024</h1>
    
    <div class="metrics-grid">
        <div class="metric-card card-events">
            <div class="metric-icon">📈</div>
            <div class="metric-value">{len(df):,}</div>
            <div class="metric-label">Tong Su Kien</div>
        </div>
        <div class="metric-card card-countries">
            <div class="metric-icon">🌍</div>
            <div class="metric-value">{df['country'].nunique()}</div>
            <div class="metric-label">Quoc Gia</div>
        </div>
        <div class="metric-card card-casualties">
            <div class="metric-icon">💔</div>
            <div class="metric-value">{df['casualties'].sum()/1e6:.1f}M</div>
            <div class="metric-label">Thuong Vong</div>
        </div>
        <div class="metric-card card-economic">
            <div class="metric-icon">💰</div>
            <div class="metric-value">${df['economic_loss_usd'].sum()/1e9:.0f}B</div>
            <div class="metric-label">Thiet Hai (USD)</div>
        </div>
    </div>
    
    <div class="insights-section">
        <div class="insight-card">
            <span class="insight-icon">🔥</span>
            <div class="insight-text">
                <div class="insight-label">Tham hoa pho bien</div>
                <div class="insight-value">{most_common_disaster}</div>
            </div>
        </div>
        <div class="insight-card">
            <span class="insight-icon">🎯</span>
            <div class="insight-text">
                <div class="insight-label">Quoc gia anh huong nhieu</div>
                <div class="insight-value">{most_affected_country}</div>
            </div>
        </div>
        <div class="insight-card">
            <span class="insight-icon">📅</span>
            <div class="insight-text">
                <div class="insight-label">Nam nhieu tham hoa</div>
                <div class="insight-value">{peak_year}</div>
            </div>
        </div>
    </div>
    
    <div class="footer-stats">
        <div class="footer-stat">
            <div class="footer-value">⏱️ {avg_response:.1f}h</div>
            <div class="footer-label">Thoi Gian Phan Ung TB</div>
        </div>
        <div class="footer-stat">
            <div class="footer-value">🔄 {avg_recovery:.0f} ngay</div>
            <div class="footer-label">Thoi Gian Hoi Phuc TB</div>
        </div>
        <div class="footer-stat">
            <div class="footer-value">📊 {df['severity_index'].mean():.1f}/10</div>
            <div class="footer-label">Muc Do Nghiem Trong TB</div>
        </div>
    </div>
</div>
"""
display(HTML(html_dashboard))
# Out:
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Inter:wght@300;400;600;700&display=swap');
#
#     .dashboard-container {
#         background: linear-gradient(135deg, #0f0f1a 0%, #1a1a2e 50%, #16213e 100%);
#         padding: 40px;
#         border-radius: 24px;
#         font-family: 'Inter', 'Segoe UI', sans-serif;
#         position: relative;
#         overflow: hidden;
#     }
#
#     .dashboard-container::before {
#         content: '';
#         position: absolute;
#         top: -50%;
#         left: -50%;
#         width: 200%;
#         height: 200%;
#         background: radial-gradient(circle, rgba(139, 92, 246, 0.1) 0%, transparent 50%);
#         animation: pulse 8s ease-in-out infinite;
#     }
#
#     @keyframes pulse {
#         0%, 100% { transform: scale(1); opacity: 0.5; }
#         50% { transform: scale(1.1); opacity: 0.8; }
#     }
#
#     .dashboard-title {
#         text-align: center;
#         font-size: 28px;
#         font-weight: 700;
#         background: linear-gradient(90deg, #60A5FA, #A78BFA, #F472B6);
#         -webkit-background-clip: text;
#         -webkit-text-fill-color: transparent;
#         margin-bottom: 30px;
#         position: relative;
#         z-index: 1;
#     }
#
#     .metrics-grid {
#         display: grid;
#         grid-template-columns: repeat(4, 1fr);
#         gap: 20px;
#         margin-bottom: 30px;
#         position: relative;
#         z-index: 1;
#     }
#
#     .metric-card {
#         background: rgba(255, 255, 255, 0.05);
#         backdrop-filter: blur(10px);
#         border: 1px solid rgba(255, 255, 255, 0.1);
#         border-radius: 16px;
#         padding: 24px;
#         text-align: center;
#         transition: all 0.3s ease;
#     }
#
#     .metric-card:hover {
#         transform: translateY(-5px);
#         box-shadow: 0 20px 40px rgba(0, 0, 0, 0.3);
#         border-color: rgba(255, 255, 255, 0.2);
#     }
#
#     .metric-icon {
#         font-size: 32px;
#         margin-bottom: 10px;
#     }
#
#     .metric-value {
#         font-size: 32px;
#         font-weight: 700;
#         margin: 8px 0;
#     }
#
#     .metric-label {
#         font-size: 12px;
#         color: rgba(255, 255, 255, 0.6);
#         text-transform: uppercase;
#         letter-spacing: 1px;
#     }
#
#     .card-events { border-top: 3px solid #F87171; }
#     .card-events .metric-value { color: #F87171; }
#
#     .card-countries { border-top: 3px solid #34D399; }
#     .card-countries .metric-value { color: #34D399; }
#
#     .card-casualties { border-top: 3px solid #FBBF24; }
#     .card-casualties .metric-value { color: #FBBF24; }
#
#     .card-economic { border-top: 3px solid #A78BFA; }
#     .card-economic .metric-value { color: #A78BFA; }
#
#     .insights-section {
#         display: grid;
#         grid-template-columns: repeat(3, 1fr);
#         gap: 16px;
#         position: relative;
#         z-index: 1;
#     }
#
#     .insight-card {
#         background: linear-gradient(135deg, rgba(99, 102, 241, 0.1), rgba(168, 85, 247, 0.1));
#         border-radius: 12px;
#         padding: 16px 20px;
#         display: flex;
#         align-items: center;
#         gap: 12px;
#         border: 1px solid rgba(255, 255, 255, 0.05);
#     }
#
#     .insight-icon {
#         font-size: 24px;
#     }
#
#     .insight-text {
#         flex: 1;
#     }
#
#     .insight-label {
#         font-size: 11px;
#         color: rgba(255, 255, 255, 0.5);
#         text-transform: uppercase;
#     }
#
#     .insight-value {
#         font-size: 14px;
#         color: #FFFFFF;
#         font-weight: 600;
#     }
#
#     .footer-stats {
#         display: flex;
#         justify-content: center;
#         gap: 40px;
#         margin-top: 25px;
#         padding-top: 20px;
#         border-top: 1px solid rgba(255, 255, 255, 0.1);
#         position: relative;
#         z-index: 1;
#     }
#
#     .footer-stat {
#         text-align: center;
#     }
#
#     .footer-value {
#         font-size: 20px;
#         font-weight: 600;
#         color: #60A5FA;
#     }
#
#     .footer-label {
#         font-size: 11px;
#         color: rgba(255, 255, 255, 0.5);
#     }
# </style>
#
# <div class="dashboard-container">
#     <h1 class="dashboard-title">📊 TONG QUAN DU LIEU THAM HOA TOAN CAU 2018-2024</h1>
#
#     <div class="metrics-grid">
#         <div class="metric-card card-events">
#             <div class="metric-icon">📈</div>
#             <div class="metric-value">50,000</div>
#             <div class="metric-label">Tong Su Kien</div>
#         </div>
#         <div class="metric-card card-countries">
#             <div class="metric-icon">🌍</div>
#             <div class="metric-value">20</div>
#             <div class="metric-label">Quoc Gia</div>
#         </div>
#         <div class="metric-card card-casualties">
#             <div class="metric-icon">💔</div>
#             <div class="metric-value">5.0M</div>
#             <div class="metric-label">Thuong Vong</div>
#         </div>
#         <div class="metric-card card-economic">
#             <div class="metric-icon">💰</div>
#             <div class="metric-value">$253B</div>
#             <div class="metric-label">Thiet Hai (USD)</div>
#         </div>
#     </div>
#
#     <div class="insights-section">
#         <div class="insight-card">
#             <span class="insight-icon">🔥</span>
#             <div class="insight-text">
#                 <div class="insight-label">Tham hoa pho bien</div>
#                 <div class="insight-value">Sat lo dat</div>
#             </div>
#         </div>
#         <div class="insight-card">
#             <span class="insight-icon">🎯</span>
#             <div class="insight-text">
#                 <div class="insight-label">Quoc gia anh huong nhieu</div>
#                 <div class="insight-value">Brazil</div>
#             </div>
#         </div>
#         <div class="insight-card">
#             <span class="insight-icon">📅</span>
#             <div class="insight-text">
#                 <div class="insight-label">Nam nhieu tham hoa</div>
#                 <div class="insight-value">2021</div>
#             </div>
#         </div>
#     </div>
#
#     <div class="footer-stats">
#         <div class="footer-stat">
#             <div class="footer-value">⏱️ 12.2h</div>
#             <div class="footer-label">Thoi Gian Phan Ung TB</div>
#         </div>
#         <div class="footer-stat">
#             <div class="footer-value">🔄 50 ngay</div>
#             <div class="footer-label">Thoi Gian Hoi Phuc TB</div>
#         </div>
#         <div class="footer-stat">
#             <div class="footer-value">📊 5.0/10</div>
#             <div class="footer-label">Muc Do Nghiem Trong TB</div>
#         </div>
#     </div>
# </div>
