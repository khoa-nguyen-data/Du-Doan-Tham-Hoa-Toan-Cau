# %% [markdown]
# # Dự đoán thiệt hại về kinh tế (dola) do thảm họa gây ra

# %% [markdown]
# # xem nhanh qua data

# %%
import pandas as pd

df = pd.read_csv("global_disaster_response_2018_2024.csv")
df.head()
# Out:
#          date        country disaster_type  severity_index  casualties  \
# 0   31/1/2021         Brazil    Earthquake            5.99         111
# 1  23/12/2018         Brazil  Extreme Heat            6.53         100
# 2   10/8/2020          India     Hurricane            1.55          22
# 3   15/9/2022      Indonesia  Extreme Heat            4.55          94
# 4   28/9/2022  United States      Wildfire            3.80          64
#
#    economic_loss_usd  response_time_hours  aid_amount_usd  \
# 0         7934365.71                15.62       271603.79
# 1         8307648.99                 5.03       265873.81
# 2          765136.99                32.54        49356.49
# 3         1308251.31                 7.83       237512.88
# 4         2655864.36                21.90       188910.69
#
#    response_efficiency_score  recovery_days  latitude  longitude
# 0                      83.21             67    -30.61    -122.56
# 1                      96.18             55     10.86    -159.19
# 2                      60.40             22      0.64    -160.98
# 3                      86.41             47    -33.55      30.35
# 4                      72.81             42    -19.17    -117.14

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       50000 non-null  object
#  1   country                    50000 non-null  object
#  2   disaster_type              50000 non-null  object
#  3   severity_index             50000 non-null  float64
#  4   casualties                 50000 non-null  int64
#  5   economic_loss_usd          50000 non-null  float64
#  6   response_time_hours        50000 non-null  float64
#  7   aid_amount_usd             50000 non-null  float64
#  8   response_efficiency_score  50000 non-null  float64
#  9   recovery_days              50000 non-null  int64
#  10  latitude                   50000 non-null  float64
#  11  longitude                  50000 non-null  float64
# dtypes: float64(7), int64(2), object(3)
# memory usage: 4.6+ MB

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
df.describe()
# Out:
#        severity_index  casualties  economic_loss_usd  response_time_hours  \
# count        50000.00    50000.00           50000.00             50000.00
# mean             5.02      100.59         5068593.45                12.18
# std              1.94       65.05         3268540.52                 9.26
# min              1.00        0.00             527.39                 1.00
# 25%              3.66       51.00         2585513.48                 6.27
# 50%              4.99       91.00         4548350.74                10.51
# 75%              6.34      138.00         6950614.61                15.45
# max             10.00      524.00        24456237.87                63.10
#
#        aid_amount_usd  response_efficiency_score  recovery_days  latitude  \
# count        50000.00                   50000.00       50000.00  50000.00
# mean        250000.33                      87.57          49.68      0.23
# std         143227.51                      10.19          20.10     34.76
# min             16.60                      29.75           2.00    -59.99
# 25%         142966.34                      83.06          36.00    -29.85
# 50%         230536.47                      89.18          49.00      0.27
# 75%         335225.93                      94.70          63.00     30.49
# max        1126465.23                     100.00         112.00     60.00
#
#        longitude
# count   50000.00
# mean        0.09
# std        98.38
# min      -170.00
# 25%       -85.55
# 50%         0.39
# 75%        85.67
# max       170.00

# %% [markdown]
#  - 0   country                    Quốc gia
#  - 1   disaster_type              Loại thảm họa
#  - 2   severity_index             mức độ thảm họa
#  - 3   casualties                 người bị ảnh hưởng
#  - 4   response_time_hours        thời gian phản ứng
#  - 5   aid_amount_usd             tổng viện trợ quốc tế
#  - 6   response_efficiency_score  điểm hiệu quả phản ứng
#  - 7   recovery_days              ngày hồi phục
#  - 8   latitude                   vĩ độ
#  - 9   longitude                  kinh độ
#  - 10  economic_loss_usd          thiệt hại kinh tế

# %%
# kiểm tra lặp
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# kiểm tra thiếu
df.isnull().sum()
# Out:
# date                         0
# country                      0
# disaster_type                0
# severity_index               0
# casualties                   0
# economic_loss_usd            0
# response_time_hours          0
# aid_amount_usd               0
# response_efficiency_score    0
# recovery_days                0
# latitude                     0
# longitude                    0
# dtype: int64

# %% [markdown]
# - dữ liệu nhiều rất sạch không lặp, không missing.

# %% [markdown]
# # Phân tích mức độ thảm họa theo thiệt hại kinh tế

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Đọc dữ liệu
df = pd.read_csv("global_disaster_response_2018_2024.csv")

# Vẽ biểu đồ scatter
plt.figure(figsize=(7,5))
plt.scatter(
    df["severity_index"],
    df["economic_loss_usd"] / 1_000_000,
    alpha=0.4
)

plt.xlabel("Mức độ thảm họa (1–10)")
plt.ylabel("Thiệt hại kinh tế (triệu USD)")
plt.title("Tương quan giữa mức độ thảm họa và thiệt hại kinh tế")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Phân tích economic_loss_usd thiệt hại do thảm họa

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.histplot(df["economic_loss_usd"] / 1_000_000, bins=50, kde=True)
plt.title("Phân bố thiệt hại kinh tế (USD)")
plt.xlabel("thiệt hại kinh tế (triệu usd)")
plt.ylabel("số lượng")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.violinplot(
    data=df,
    x=df["disaster_type"],
    y=df["economic_loss_usd"] / 1_000_000,
    scale="width"
)
plt.xticks(rotation=45)
plt.title("So sánh mức độ thiệt hại của các loại thiên tai")
plt.tight_layout()
plt.xlabel("Loại thiên tai")
plt.ylabel("thiệt hại kinh tế (triệu usd)")
plt.show()
# Out:
# C:\Users\khoa\AppData\Local\Temp\ipykernel_7432\1670841960.py:2: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(

# %% [markdown]
# Các loại thiên tai gây thiệt hại trung bình ngang nhau thiệt hại kinh tế nặng nhất là hạn hán, núi lửa phun trào và lụt có thiệt hại trung bình cao hơn các loại khác

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5,4))
plt.scatter(
    df["casualties"],
    df["economic_loss_usd"] / 1_000_000,
    alpha=0.4
)
plt.xlabel("Thương vong")
plt.ylabel("Thiệt hại kinh tế (triệu USD)")
plt.title("Thương vong và thiệt hại kinh tế")
plt.tight_layout()
plt.show()

# %% [markdown]
# - Thương vong tăng => thiệt hại kinh tế tăng, biểu đồ có thể hiện nhưng không rõ lắm

# %%
plt.figure(figsize=(5,4))
plt.scatter(
    df["response_time_hours"],
    df["economic_loss_usd"]/1_000_000,
    alpha=0.4
)
plt.xlabel("thời gian phản ứng (giờ)")
plt.ylabel("Thiệt hại kinh tế (triệu USD)")
plt.title("thời gian phản ứng với thiệt hại kinh tế ")
plt.tight_layout()
plt.show()

# %%
- thời gian phản ứng càng nhanh thiệt hại càng lớn => thảm họa thiệt hại kinh tế càng lớn phản ứng càng nhanh

# %%
plt.figure(figsize=(5,4))
plt.scatter(
    df["aid_amount_usd"],
    df["economic_loss_usd"],
    alpha=0.4
)
plt.xlabel("Aid Amount (USD)")
plt.ylabel("Economic Loss (USD)")
plt.title("Tổng viện trợ với thiệt hại kinh tế")
plt.tight_layout()
plt.show()

# %% [markdown]
# - biểu đồ thể hiện được tổng viện trợ quốc tế tăng thì thiệt hại kinh tế lớn

# %%
import numpy as np

log_df = df[cols].apply(np.log1p)

plt.figure(figsize=(6,5))
sns.heatmap(
    log_df.corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)
plt.title("Correlation Heatmap (Log Scale)")
plt.tight_layout()
plt.show()

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.1.2-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\khoa\appdata\local\programs\python\python312\lib\site-packages (from xgboost) (2.2.6)
# Requirement already satisfied: scipy in c:\users\khoa\appdata\local\programs\python\python312\lib\site-packages (from xgboost) (1.16.3)
# Downloading xgboost-3.1.2-py3-none-win_amd64.whl (72.0 MB)
#    ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#    ---------------------------------------- 0.8/72.0 MB 11.2 MB/s eta 0:00:07
#    ------- -------------------------------- 12.8/72.0 MB 50.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 21.0/72.0 MB 55.2 MB/s eta 0:00:01
#    ------------------- -------------------- 35.7/72.0 MB 55.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 40.9/72.0 MB 46.4 MB/s eta 0:00:01
#    --------------------------------- ------ 60.0/72.0 MB 56.3 MB/s eta 0:00:01
#    ---------------------------------------- 72.0/72.0 MB 56.7 MB/s  0:00:01
# Installing collected packages: xgboost
# Successfully installed xgboost-3.1.2

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from xgboost import XGBRegressor

# %%
df = pd.read_csv("global_disaster_response_2018_2024.csv")

# %%
FEATURES = [
    "country",
    "disaster_type",
    "severity_index",
    "casualties",
    "response_time_hours",
    "aid_amount_usd",
    "response_efficiency_score",
    "recovery_days"
]

TARGET = "economic_loss_usd"

X = df[FEATURES].copy()
y = df[TARGET].copy()

# %%
log_cols = ["aid_amount_usd"]

for col in log_cols:
    X[col] = np.log1p(X[col])

# %%
y_log = np.log1p(y)

# %%
cat_cols = ["country", "disaster_type"]
num_cols = [c for c in FEATURES if c not in cat_cols]

preprocess = ColumnTransformer(
    transformers=[
        ("cat", Pipeline([
            ("imputer", SimpleImputer(strategy="most_frequent")),
            ("onehot", OneHotEncoder(handle_unknown="ignore"))
        ]), cat_cols),

        ("num", Pipeline([
            ("imputer", SimpleImputer(strategy="median"))
        ]), num_cols)
    ]
)

# %%
X_train, X_test, y_train_log, y_test_log = train_test_split(
    X, y_log, test_size=0.2, random_state=42
)

# %%
xgb_model = XGBRegressor(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    objective="reg:squarederror",
    random_state=42,
    n_jobs=-1
)

# %%
pipe = Pipeline(steps=[
    ("preprocess", preprocess),
    ("model", xgb_model)
])

pipe.fit(X_train, y_train_log)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['country', 'disaster_type']),
#                                                  ('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['severity_index',
#                                                    'casualties',
#                                                    'response_time_hours',
#                                                    'aid_amou...
#                               feature_types=None, feature_weights=None,
#                               gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=0.05,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=6, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=300, n_jobs=-1,
#                               num_parallel_tree=None, ...))])

# %%
# Predict trên log-scale
y_pred_log = pipe.predict(X_test)

# Chuyển về USD thật
y_pred = np.expm1(y_pred_log)
y_test_real = np.expm1(y_test_log)

# %%
mae = mean_absolute_error(y_test_real, y_pred)
rmse = np.sqrt(mean_squared_error(y_test_real, y_pred))
r2 = r2_score(y_test_real, y_pred)

print("MAE :", mae)
print("RMSE:", rmse)
print("R2  :", r2)
# Out:
# MAE : 2087116.7374847503
# RMSE: 2780984.599501147
# R2  : 0.2720942109999219

# %%
custom_sample = pd.DataFrame([{
    "country": "Brazil",
    "disaster_type": "Earthquake",
    "severity_index": 5.99,
    "casualties": np.log1p(111),
    "response_time_hours": np.log1p(15.62),
    "aid_amount_usd": np.log1p(271603.79),
    "response_efficiency_score": 83.21,
    "recovery_days": 67
}])

# kết quả đúng 7,934,365.71 USD
pred_log = pipe.predict(custom_sample)
pred_usd = np.expm1(pred_log)

print(f"Dự đoán economic_loss_usd: {pred_usd[0]:,.2f} USD")
# Out:
# Dự đoán economic_loss_usd: 4,830,800.50 USD

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))
plt.scatter(y_test_real, y_pred, alpha=0.4)

plt.plot(
    [y_test_real.min(), y_test_real.max()],
    [y_test_real.min(), y_test_real.max()],
    color="red",
    linestyle="--"
)

plt.xlabel("Thiệt hại kinh tế thực tế (USD)")
plt.ylabel("Thiệt hại kinh tế dự đoán (USD)")
plt.title("Thiệt hại kinh tế dự đoán so với thực tế")
plt.tight_layout()
plt.show()

# %% [markdown]
# -XGBOOST dự đoán các giá trị thiệt hại cao tốt hơn RFR nhưng tổng thể mô hình vẫn tệ

# %% [markdown]
# -XGBoost sau khi LogTrainForm biến mục tiêu thì tệ hơn lúc chưa Log
